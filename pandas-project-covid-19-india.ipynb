# %% [markdown]
# ## COURSE PROJECT - ZERO TO PANDAS

# %% [markdown]
# ## ANALYSIS OF COVID-19 CASES IN INDIA

# %% [markdown]
# ## The aim of this project is to study the trends of the Covid-19 cases in India considering Delhi as an example

# %%
# Let's install jovian.

# !pip install jovian --upgrade --quiet

# %%
# Let's import jovian and the required libraries

import jovian
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Downloading the Dataset and Loading it into a dataframe

# %%
# We are reading the csv file from our computer which is already downloaded.

# Link from where I got the dataset.

# https://www.kaggle.com/imdevskp/covid19-corona-virus-india-dataset.
    
india_df = pd.read_csv("C:\\complete india data.csv")

# %% [markdown]
# ## Data Preparation, Cleaning and Exploratory Analysis

# %%
# Let's have a look at the type of india_df

type(india_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Let's have a look at our dataframe

india_df
# Out:
#            Date Name of State / UT  Latitude  Longitude  \
# 0     1/30/2020             Kerala   10.8505    76.2711
# 1     1/31/2020             Kerala   10.8505    76.2711
# 2      2/1/2020             Kerala   10.8505    76.2711
# 3      2/2/2020             Kerala   10.8505    76.2711
# 4      2/3/2020             Kerala   10.8505    76.2711
# ...         ...                ...       ...        ...
# 4687   8/6/2020          Telangana   18.1124    79.0193
# 4688   8/6/2020            Tripura   23.9408    91.9882
# 4689   8/6/2020      Uttar Pradesh   26.8467    80.9462
# 4690   8/6/2020        Uttarakhand   30.0668    79.0193
# 4691   8/6/2020        West Bengal   22.9868    87.8550
#
#       Total_Confirmed_cases Death  Cured/Discharged/Migrated  New_cases  \
# 0                         1     0                          0          0
# 1                         1     0                          0          0
# 2                         2     0                          0          1
# ...

# %%
# To check if there are any null values

pd.isnull(india_df).any()
# Out:
# Date                         False
# Name of State / UT           False
# Latitude                     False
# Longitude                    False
# Total_Confirmed_cases        False
# Death                        False
# Cured/Discharged/Migrated    False
# New_cases                    False
# New_deaths                   False
# New_recovered                False
# dtype: bool

# %%
# We have set the index of the dataframe to Name of the State/ UT

state_df = india_df.set_index('Name of State / UT')
state_df
# Out:
#                          Date  Latitude  Longitude  Total_Confirmed_cases  \
# Name of State / UT
# Kerala              1/30/2020   10.8505    76.2711                      1
# Kerala              1/31/2020   10.8505    76.2711                      1
# Kerala               2/1/2020   10.8505    76.2711                      2
# Kerala               2/2/2020   10.8505    76.2711                      3
# Kerala               2/3/2020   10.8505    76.2711                      3
# ...                       ...       ...        ...                    ...
# Telangana            8/6/2020   18.1124    79.0193                  73050
# Tripura              8/6/2020   23.9408    91.9882                   5725
# Uttar Pradesh        8/6/2020   26.8467    80.9462                 104388
# Uttarakhand          8/6/2020   30.0668    79.0193                   8254
# West Bengal          8/6/2020   22.9868    87.8550                  83800
#
# ...

# %%
# We have extracted the data for Delhi from the India dataframe.i.e.india_df

delhi_df = state_df.loc['Delhi']

# %%
# let's have a look at our Delhi Dataframe 

delhi_df
# Out:
#                         Date  Latitude  Longitude  Total_Confirmed_cases  \
# Name of State / UT
# Delhi               3/2/2020   28.7041    77.1025                      1
# Delhi               3/3/2020   28.7041    77.1025                      1
# Delhi               3/4/2020   28.7041    77.1025                      1
# Delhi               3/5/2020   28.7041    77.1025                      2
# Delhi               3/6/2020   28.7041    77.1025                      3
# ...                      ...       ...        ...                    ...
# Delhi               8/2/2020   28.7041    77.1025                 136716
# Delhi               8/3/2020   28.7041    77.1025                 137677
# Delhi               8/4/2020   28.7041    77.1025                 138482
# Delhi               8/5/2020   28.7041    77.1025                 139156
# Delhi               8/6/2020   28.7041    77.1025                 140232
#
# ...

# %%
# Use the .info method to get an overview of your data

delhi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154 entries, Delhi to Delhi
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       154 non-null    object
#  1   Latitude                   154 non-null    float64
#  2   Longitude                  154 non-null    float64
#  3   Total_Confirmed_cases      154 non-null    int64
#  4   Death                      154 non-null    object
#  5   Cured/Discharged/Migrated  154 non-null    int64
#  6   New_cases                  154 non-null    int64
#  7   New_deaths                 154 non-null    int64
#  8   New_recovered              154 non-null    int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 12.0+ KB

# %%
# Use the .describe method to get the various statistical values in your dataframe

delhi_df.describe()
# Out:
#            Latitude     Longitude  Total_Confirmed_cases  \
# count  1.540000e+02  1.540000e+02             154.000000
# mean   2.870410e+01  7.710250e+01           37442.363636
# std    4.990027e-14  2.423727e-13           48596.338131
# min    2.870410e+01  7.710250e+01               1.000000
# 25%    2.870410e+01  7.710250e+01             681.750000
# 50%    2.870410e+01  7.710250e+01            9693.500000
# 75%    2.870410e+01  7.710250e+01           69443.000000
# max    2.870410e+01  7.710250e+01          140232.000000
#
#        Cured/Discharged/Migrated    New_cases  New_deaths  New_recovered
# count                 154.000000   154.000000       154.0     154.000000
# mean                27307.525974   910.590909         0.0     818.935065
# std                 41489.296026  1157.010022         0.0    1308.333000
# min                     0.000000     0.000000         0.0       0.000000
# 25%                    22.000000    55.750000         0.0       1.000000
# ...

# %%
# Use the .columns method to get a list of all the column names in the dataframe

delhi_df.columns
# Out:
# Index(['Date', 'Latitude', 'Longitude', 'Total_Confirmed_cases', 'Death',
#        'Cured/Discharged/Migrated', 'New_cases', 'New_deaths',
#        'New_recovered'],
#       dtype='object')

# %%
# Use the .shape methos to know the size of your dataframe. 
# This gives you the number of rows and number of columns in the dataframe.

delhi_df.shape
# Out:
# (154, 9)

# %%
# Use the .head method to get the values of the first 5 rows

delhi_df.head(5)
# Out:
#                         Date  Latitude  Longitude  Total_Confirmed_cases  \
# Name of State / UT
# Delhi               3/2/2020   28.7041    77.1025                      1
# Delhi               3/3/2020   28.7041    77.1025                      1
# Delhi               3/4/2020   28.7041    77.1025                      1
# Delhi               3/5/2020   28.7041    77.1025                      2
# Delhi               3/6/2020   28.7041    77.1025                      3
#
#                    Death  Cured/Discharged/Migrated  New_cases  New_deaths  \
# Name of State / UT
# Delhi                  0                          0          0           0
# Delhi                  0                          0          0           0
# Delhi                  0                          0          0           0
# Delhi                  0                          0          1           0
# Delhi                  0                          0          1           0
#
#                     New_recovered
# ...

# %%
# Use the .tail methos to get the values of the last 5 rows

delhi_df.tail(5)
# Out:
#                         Date  Latitude  Longitude  Total_Confirmed_cases  \
# Name of State / UT
# Delhi               8/2/2020   28.7041    77.1025                 136716
# Delhi               8/3/2020   28.7041    77.1025                 137677
# Delhi               8/4/2020   28.7041    77.1025                 138482
# Delhi               8/5/2020   28.7041    77.1025                 139156
# Delhi               8/6/2020   28.7041    77.1025                 140232
#
#                    Death  Cured/Discharged/Migrated  New_cases  New_deaths  \
# Name of State / UT
# Delhi               3989                     122131       1118           0
# Delhi               4004                     123317        961           0
# Delhi               4021                     124254        805           0
# Delhi               4033                     125226        674           0
# Delhi               4044                     126116       1076           0
#
#                     New_recovered
# ...

# %%
# Use the .sample method to get a random sample of the data

delhi_df.sample(5)
# Out:
#                          Date  Latitude  Longitude  Total_Confirmed_cases  \
# Name of State / UT
# Delhi               7/16/2020   28.7041    77.1025                 116993
# Delhi               6/16/2020   28.7041    77.1025                  42829
# Delhi               6/20/2020   28.7041    77.1025                  53116
# Delhi               3/10/2020   28.7041    77.1025                      4
# Delhi               7/24/2020   28.7041    77.1025                 127364
#
#                    Death  Cured/Discharged/Migrated  New_cases  New_deaths  \
# Name of State / UT
# Delhi               3487                      95699       1647           0
# Delhi               1400                      16427       1647           0
# Delhi               2035                      23569       3137           0
# Delhi                  0                          0          0           0
# Delhi               3745                     109065       1041           0
#
# ...

# %% [markdown]
# ## Asking and Answering Questions

# %% [markdown]
# ## Question 1
#
# On which day, most number to cases were confirmed in delhi?

# %%
# Here we have sorted the values based on the descending order of Total_Confirmed_cases.
# We have used the .head method to retrive the top 5 values.
# The top most value is the most number of cases confirmed.

delhi_df.sort_values('Total_Confirmed_cases', ascending=False).head(5)
# Out:
#                         Date  Latitude  Longitude  Total_Confirmed_cases  \
# Name of State / UT
# Delhi               8/6/2020   28.7041    77.1025                 140232
# Delhi               8/5/2020   28.7041    77.1025                 139156
# Delhi               8/4/2020   28.7041    77.1025                 138482
# Delhi               8/3/2020   28.7041    77.1025                 137677
# Delhi               8/2/2020   28.7041    77.1025                 136716
#
#                    Death  Cured/Discharged/Migrated  New_cases  New_deaths  \
# Name of State / UT
# Delhi               4044                     126116       1076           0
# Delhi               4033                     125226        674           0
# Delhi               4021                     124254        805           0
# Delhi               4004                     123317        961           0
# Delhi               3989                     122131       1118           0
#
#                     New_recovered
# ...

# %% [markdown]
# The most number of confirmed cases were reported on 6th August 2020 in Delhi.

# %% [markdown]
# ## Question 2
#
# On which day, least number of cases were reported in Delhi?

# %%
# Here we have sorted the values based on the descending order of Total_Confirmed_cases.
# We have used the .tail method to retrive the bottom 5 values.
# The bottom most value is the least number of cases confirmed.

delhi_df.sort_values('Total_Confirmed_cases', ascending=False).tail(5)
# Out:
#                         Date  Latitude  Longitude  Total_Confirmed_cases  \
# Name of State / UT
# Delhi               3/7/2020   28.7041    77.1025                      3
# Delhi               3/5/2020   28.7041    77.1025                      2
# Delhi               3/4/2020   28.7041    77.1025                      1
# Delhi               3/3/2020   28.7041    77.1025                      1
# Delhi               3/2/2020   28.7041    77.1025                      1
#
#                    Death  Cured/Discharged/Migrated  New_cases  New_deaths  \
# Name of State / UT
# Delhi                  0                          0          0           0
# Delhi                  0                          0          1           0
# Delhi                  0                          0          0           0
# Delhi                  0                          0          0           0
# Delhi                  0                          0          0           0
#
#                     New_recovered
# ...

# %% [markdown]
# The least number of confirmed cases were reported on 2nd,3rd and 4th of March 2020 in Delhi.

# %% [markdown]
# ## Question 3
#
# On which day, most number of deaths took place in Delhi?

# %%
# Here we have sorted the values based on the descending order of Death.
# We have used the .head method to retrive the top 5 values.
# The top most value is the most number of deaths.

delhi_df.sort_values('Death', ascending=False).head(5)
# Out:
#                          Date  Latitude  Longitude  Total_Confirmed_cases  \
# Name of State / UT
# Delhi               6/11/2020   28.7041    77.1025                  32810
# Delhi               6/10/2020   28.7041    77.1025                  31309
# Delhi                4/9/2020   28.7041    77.1025                    669
# Delhi                4/8/2020   28.7041    77.1025                    576
# Delhi                6/9/2020   28.7041    77.1025                  29943
#
#                    Death  Cured/Discharged/Migrated  New_cases  New_deaths  \
# Name of State / UT
# Delhi                984                      12245       1501           0
# Delhi                905                      11861       1366           0
# Delhi                  9                         21         93           0
# Delhi                  9                         21         53           0
# Delhi                874                      11357       1007           0
#
# ...

# %% [markdown]
# The most number of deaths took place on 11th June 2020 in Delhi.

# %% [markdown]
# ## Question 4
#
# On which day, most of the people got cured/discharged/migrated in Delhi?

# %%
# Here we have sorted the values based on the descending order of Cured/Discharged/Migrated.
# We have used the .head method to retrive the top 5 values.
# The top most value is the most number of people who got Cured/Discharged/Migrated.

delhi_df.sort_values('Cured/Discharged/Migrated', ascending=False).head(5)
# Out:
#                         Date  Latitude  Longitude  Total_Confirmed_cases  \
# Name of State / UT
# Delhi               8/6/2020   28.7041    77.1025                 140232
# Delhi               8/5/2020   28.7041    77.1025                 139156
# Delhi               8/4/2020   28.7041    77.1025                 138482
# Delhi               8/3/2020   28.7041    77.1025                 137677
# Delhi               8/2/2020   28.7041    77.1025                 136716
#
#                    Death  Cured/Discharged/Migrated  New_cases  New_deaths  \
# Name of State / UT
# Delhi               4044                     126116       1076           0
# Delhi               4033                     125226        674           0
# Delhi               4021                     124254        805           0
# Delhi               4004                     123317        961           0
# Delhi               3989                     122131       1118           0
#
#                     New_recovered
# ...

# %% [markdown]
# The most number of people who were cured/discharged/migrated on 6th August 2020 in Delhi.

# %% [markdown]
# ## Question 5
#
# On which day, most of the people got recovered in Delhi?

# %%
# Here we have sorted the values based on the descending order of New_recovered.
# We have used the .head method to retrive the top 5 values.
# The top most value is the most number of people who newly recovered.

delhi_df.sort_values('New_recovered', ascending=False).head(5)
# Out:
#                          Date  Latitude  Longitude  Total_Confirmed_cases  \
# Name of State / UT
# Delhi               6/21/2020   28.7041    77.1025                  56746
# Delhi               6/27/2020   28.7041    77.1025                  77240
# Delhi                7/5/2020   28.7041    77.1025                  97200
# Delhi               7/10/2020   28.7041    77.1025                 107051
# Delhi                7/9/2020   28.7041    77.1025                 104864
#
#                    Death  Cured/Discharged/Migrated  New_cases  New_deaths  \
# Name of State / UT
# Delhi               2112                      31294       3630           0
# Delhi               2492                      47091       6850           0
# Delhi               3004                      68256       5025           0
# Delhi               3258                      82226       2187           0
# Delhi               3213                      78199       2033           0
#
# ...

# %% [markdown]
# Most people recovered on 21st June 2020 in Delhi.

# %% [markdown]
# ## Question 6
#
# On which day, most number of new cases were reported?

# %%
# Here we have sorted the values based on the descending order of New_cases.
# We have used the .head method to retrive the top 5 values.
# The top most value is the most number of newly reported cases.

delhi_df.sort_values('New_cases', ascending=False).head(5)
# Out:
#                          Date  Latitude  Longitude  Total_Confirmed_cases  \
# Name of State / UT
# Delhi               6/27/2020   28.7041    77.1025                  77240
# Delhi                7/5/2020   28.7041    77.1025                  97200
# Delhi                7/2/2020   28.7041    77.1025                  89802
# Delhi               6/24/2020   28.7041    77.1025                  66602
# Delhi               6/25/2020   28.7041    77.1025                  70390
#
#                    Death  Cured/Discharged/Migrated  New_cases  New_deaths  \
# Name of State / UT
# Delhi               2492                      47091       6850           0
# Delhi               3004                      68256       5025           0
# Delhi               2803                      59992       4641           0
# Delhi               2301                      39313       3947           0
# Delhi               2365                      41437       3788           0
#
# ...

# %% [markdown]
# Most number of new cases were reported on 27th June 2020 in Delhi.

# %% [markdown]
# ## Visualization

# %%
# Here we have plotted the Total_Confirmed_cases.

plt.hist(delhi_df.Total_Confirmed_cases);
plt.xlabel('No of cases in thousands')
# Out:
# Text(0.5, 0, 'No of cases in thousands')

# %%
# Here we have plotted the New_cases.

plt.hist(delhi_df.New_cases);
plt.xlabel('No of cases in thousands')
# Out:
# Text(0.5, 0, 'No of cases in thousands')

# %%
# Here we have plotted the New_recovered.

plt.hist(delhi_df.New_recovered);
plt.xlabel('No of cases in thousands')
# Out:
# Text(0.5, 0, 'No of cases in thousands')

# %%
# Here we have plotted the New_cases and New_recovered.

plt.plot(delhi_df.New_cases, delhi_df.New_recovered, 's-b')
plt.xlabel('No of cases in thousands')
plt.ylabel('No of people recovered')
# Out:
# Text(0, 0.5, 'No of people recovered')

# %% [markdown]
# ## Inferences

# %% [markdown]
# From the analysis its clear that the number of cases reported was more in march and kept increasing.
# We can also observe that the number of people cured and recovered is more in July and August.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this project, we have loaded the covid-19 cases data of India and analysed the data of Delhi in particular.
# We have discovered many great insights about the trends it is following.
